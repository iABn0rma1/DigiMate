# %%
! pip install -r https://raw.githubusercontent.com/nvidia-riva/python-clients/main/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.4/863.4 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 47.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 16.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.69.0
#     Uninstalling grpcio-1.69.0:
#       Successfully uninstalled grpcio-1.69.0
# ...

# %%
! pip install --force-reinstall git+https://github.com/nvidia-riva/python-clients.git
# Out:
# ...
#   Cloning https://github.com/nvidia-riva/python-clients.git to /tmp/pip-req-build-gvrr56hc
#   Running command git clone --filter=blob:none --quiet https://github.com/nvidia-riva/python-clients.git /tmp/pip-req-build-gvrr56hc
#   Resolved https://github.com/nvidia-riva/python-clients.git to commit 30e50bb4f73f80ff2e7cedbda42c1f5d2fb2d24c
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached setuptools-70.0.0-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached grpcio-1.67.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# ...
#   Using cached grpcio_tools-1.67.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# ...
#   Using cached protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Using cached grpcio-1.67.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# ...

# %%
! git clone https://github.com/nvidia-riva/python-clients.git
# Out:
# Cloning into 'python-clients'...
# remote: Enumerating objects: 2060, done.
# remote: Counting objects: 100% (306/306), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 2060 (delta 248), reused 190 (delta 182), pack-reused 1754 (from 3)
# Receiving objects: 100% (2060/2060), 4.52 MiB | 16.97 MiB/s, done.
# Resolving deltas: 100% (1214/1214), done.

# %%
! python python-clients/scripts/tts/talk.py \
    --server grpc.nvcf.nvidia.com:443 --use-ssl \
    --metadata function-id "5e607c81-7aa6-44ce-a11d-9e08f0a3fe49"  \
    --metadata authorization "Bearer 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" \
    --list-voices
# Out:
# {
#     "en-US": {
#         "voices": [
#             "English-US-RadTTS.Female-1",
#             "English-US-RadTTS.Male-1",
#             "English-US-RadTTS.Female-Neutral",
#             "English-US-RadTTS.Male-Neutral",
#             "English-US-RadTTS.Female-Angry",
#             "English-US-RadTTS.Male-Angry",
#             "English-US-RadTTS.Female-Calm",
#             "English-US-RadTTS.Male-Calm",
#             "English-US-RadTTS.Female-Fearful",
#             "English-US-RadTTS.Female-Happy",
#             "English-US-RadTTS.Male-Happy",
#             "English-US-RadTTS.Female-Sad"
#         ]
#     }
# }

# %%
! python python-clients/scripts/tts/talk.py \
    --server grpc.nvcf.nvidia.com:443 --use-ssl \
    --metadata function-id "5e607c81-7aa6-44ce-a11d-9e08f0a3fe49"  \
    --metadata authorization "Bearer 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" \
    --text "Meow!  Hi there! I saw the funniest thing!  A little bird tried to steal a shiny button!  It wobbled and dropped it. I learned buttons aren't tasty!  Then, I helped the bird find a yummy berry.  Learning is fun, even when things are wobbly!  Purrfect day!" \
    --voice "English-US-RadTTS.Female-Happy" \
    --output audio.wav
# Out:
# Generating audio for request...
# Time spent: 2.364s

# %%
from IPython.display import Audio, display
display(Audio(data="audio.wav", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
